# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorManzini/SERS_ativ/blob/main/AULA_06_SERS_ML_Energia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##EXERCÍCIO
#
# Treinar um modelo preditivo de classificação binária. O modelo fará previsões com base nos dados da coluna 'stabf' mostrando se a rede elétrica está INSTÁVEL ou ESTÁVEL. utilizar o algoritmo Regressão Logística (Logistic Regression do sklearn) para treinamento do modelo. Avaliar o modelo com base na acurácia. Apresentar a Matriz de Confusão.

# %%
# Manupulação de tabelas e matrizes
import pandas as pd
import matplotlib as plt
# Gráficos
import numpy as np
import seaborn as sns
# Algoritmo de regressão logística
from sklearn.linear_model import LogisticRegression
# Ferramenta para separação dos dados de treino e teste
# X_train, X_test, Y_train, Y_test
from sklearn.model_selection import train_test_split
# Avaliação com acurácia e matriz de confusão
from sklearn.metrics import accuracy_score, confusion_matrix
